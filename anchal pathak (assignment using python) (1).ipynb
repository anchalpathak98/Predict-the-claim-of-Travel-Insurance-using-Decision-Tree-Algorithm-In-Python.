# %%
import numpy as np
import pandas as pd
from IPython.display import Image
from io import StringIO

# %%
x = ['w', 'x','u', 'e', 'x']
print(x[1:3])
# Out:
# ['x', 'u']

# %%
pip install pydotplus
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
z "classification"
print (z)
# Out:
#   File "<ipython-input-2-f7b66b5e79ed>", line 1
#     z "classification"
#                      ^
# SyntaxError: invalid syntax

# %%
import pydotplus
from sklearn import preprocessing
from sklearn import tree
# %matplotlib inline

# %%
import os
os.environ["PATH"] += os.pathsep + 'C:\Program Files (x86)\Graphviz2.38/bin/'

# %%
pip install DataFrame
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
col_names = ['Agency' ,'Agency Type', 'Distribution Channel', 'Product Name', 'Duration', 'Destination', 'Net Sales', 'Commision', 'Gender', 'Age', 'Claim']

# %%
pwd
# Out:
# 'C:\\Users\\dell\\Downloads'

# %%
cd= r'C:\Users\dell\Documents'

# %%
df= pd.read_excel('travelinsurance1234.xlsx',header=None, names=col_names, skiprows=1)
df.head()
# Out:
#   Agency    Agency Type Distribution Channel                     Product Name  \
# 0    CBH  Travel Agency              Offline               Comprehensive Plan
# 1    CBH  Travel Agency              Offline               Comprehensive Plan
# 2    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
# 3    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
# 4    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
#
#    Duration Destination  Net Sales  Commision Gender  Age  Claim
# 0       186    MALAYSIA      -29.0       9.57      F   81      0
# 1       186    MALAYSIA      -29.0       9.57      F   71      0
# 2        65   AUSTRALIA      -49.5      29.70      M   32      0
# 3        60   AUSTRALIA      -39.6      23.76      F   32      0
# 4        79       ITALY      -19.8      11.88      F   41      0

# %%
df = pd.get_dummies(df)

# %%
df
# Out:
#     Duration  Net Sales  Commision  Age  Claim  Agency_C2B  Agency_CBH  \
# 0        186     -29.00       9.57   81      0           0           1
# 1        186     -29.00       9.57   71      0           0           1
# 2         65     -49.50      29.70   32      0           0           0
# 3         60     -39.60      23.76   32      0           0           0
# 4         79     -19.80      11.88   41      0           0           0
# 5         66    -121.00      42.35   44      0           0           0
# 6         47     -39.60      23.76   32      0           0           0
# 7         63    -108.90      65.34   29      0           0           0
# 8         57     -19.80      11.88   44      0           0           0
# 9        186     -99.00      59.40   37      0           0           0
# 10        33     -26.00       9.10   78      0           0           0
# 11         1     -18.00       6.30   47      0           0           0
# ...

# %%
X_train = df.loc[:,df.columns != 'Claim']

# %%
Y_train = df.Claim

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn import metrics

# %%
feature_cols = ['Agency' ,'Agency Type', 'Distribution Channel', 'Product Name', 'Duration', 'Destination', 'Net Sales', 'Commision', 'Gender', 'Age']

# %%
clf = tree.DecisionTreeClassifier(criterion='entropy')

# %%
clf = clf.fit(X_train,Y_train)

# %%
def plot_decision_tree(clf,feature_name,target_name):
    dot_data = StringIO()
    tree.export_graphviz(clf, out_file=dot_data,
                         feature_names=feature_name,
                         class_names=target_name,
                         filled=True, rounded=True,
                         special_characters=True)
    graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
    return Image(graph.create_png())

# %%
tree.plot_tree(clf);
